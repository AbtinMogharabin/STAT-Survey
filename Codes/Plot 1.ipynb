# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# Out:
# c:\python\python382\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\python\python382\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# c:\python\python382\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
df= pd.read_csv('data.csv')

# %%
df.describe()
# Out:
#                   StartDate              EndDate      Status      IPAddress  \
# count                   277                  277         277            277
# unique                  276                  276           4            262
# top     2022-12-18 17:16:13  2022-12-18 18:22:56  IP Address  95.183.240.91
# freq                      2                    2         273              4
#
#        Progress Duration (in seconds) Finished         RecordedDate  \
# count       277                   277      277                  277
# unique       20                   241        4                  276
# top         100                    18     True  2022-12-25 18:22:57
# freq        210                     4      210                    2
#
#          ResponseId    RecipientLastName  ...                    8.6_1  \
# count           277                    2  ...                      190
# unique          277                    2  ...                        5
# top     Response ID  Recipient Last Name  ...  Sometimes problematic\t
# freq              1                    1  ...                       79
#
#                     8.6_2                 8.6_3                    8.6_4  \
# count                 189                   155                      194
# unique                  5                     5                        5
# top     Not problematic\t  Always problematic\t  Sometimes problematic\t
# freq                   84                    88                       97
#
#                           8.6_5                    8.6_6  \
# count                       182                      171
# unique                        5                        5
# top     Sometimes problematic\t  Sometimes problematic\t
# freq                         75                       79
#
#                        8.6_7 8.6_7_TEXT                 8.7 9.1
# count                     17         12                 199  75
# unique                     5         11                   7  73
# top     Always problematic\t    Racism   Somewhat satisfied  No
# freq                       9          2                 132   3
#
# [4 rows x 108 columns]

# %%
df.dtypes
# Out:
# StartDate     object
# EndDate       object
# Status        object
# IPAddress     object
# Progress      object
#                ...
# 8.6_6         object
# 8.6_7         object
# 8.6_7_TEXT    object
# 8.7           object
# 9.1           object
# Length: 108, dtype: object

# %%
df = df.rename(columns=df.iloc[0]).loc[1:]

# %%
df.drop(list(df.columns)[:18], axis=1, inplace=True)
df=df.drop(1)

# %%
df['2.4   How old are you?'] = pd.to_numeric(df['2.4   How old are you?'])

# %%
pd.set_option('display.max_rows', None)
df.isnull().sum(axis = 0)
# Out:
# 1.1   I am/was an international student at a Turkish university.                                                                                                                                          0
# 2.1   What is your country of citizenship?                                                                                                                                                               33
# 2.2   Do you have dual citizenship?                                                                                                                                                                      33
# 2.3   If yes, What is your secondary citizenship?                                                                                                                                                       259
# 2.4   How old are you?                                                                                                                                                                                   51
# 2.5  How do you identify yourself?                                                                                                                                                                       50
# 2.6   What is your current marital status?                                                                                                                                                               50
# 2.7   What is your level of education? - Selected Choice                                                                                                                                                 50
# 2.7   What is your level of education? - If other please specify - Text                                                                                                                                 273
# 2.8  Please name your college/university                                                                                                                                                                 51
# 2.9   When did you begin your program? - Semester                                                                                                                                                        60
# 2.9   When did you begin your program? - Year                                                                                                                                                            65
# 2.10   What is your major?                                                                                                                                                                               57
# 2.11   Do you work a part-time job during your study in Turkey?                                                                                                                                          57
# 2.12   If yes, how many hours do you work per week?                                                                                                                                                     245
# 3.1   What type of school did you attend? - Selected Choice                                                                                                                                              58
# 3.1   What type of school did you attend? - If other please specify - Text                                                                                                                              273
# 3.2   Aside from your native language, did you learn other languages at school?                                                                                                                          58
# 3.3   If yes, please specify which language(s) and the level of command. - First language                                                                                                               118
# 3.3   If yes, please specify which language(s) and the level of command. - First language - Text                                                                                                        100
# 3.3   If yes, please specify which language(s) and the level of command. - Second language                                                                                                              121
# 3.3   If yes, please specify which language(s) and the level of command. - Second language - Text                                                                                                       124
# 3.3   If yes, please specify which language(s) and the level of command. - Third language                                                                                                               176
# 3.3   If yes, please specify which language(s) and the level of command. - Third language - Text                                                                                                        183
# 3.4   Did the staff of your school provide information about opportunities to study abroad?                                                                                                              64
# 4.1   Did you come to Turkey as an exchange student?                                                                                                                                                     65
# 4.2   Through which exchange program did you come to Turkey? - Selected Choice                                                                                                                          270
# 4.2   Through which exchange program did you come to Turkey? - If other please specify - Text                                                                                                           274
# 4.3   How many semesters did you stay at the host institution?                                                                                                                                          272
# 4.4   Would you encourage others to apply for exchange program in turkey?                                                                                                                               270
# 5.1   Would you have studied in your country if the university you preferred accepted you?                                                                                                               73
# 5.2   Did the limited number of study programs in your major at home impact your decision to study abroad?                                                                                               73
# 5.3   Was Turkey your first choice to study abroad?                                                                                                                                                      74
# 5.4   If you did not choose Turkey as your first study abroad destination, which country did you originally choose? - Selected Choice                                                                   140
# 5.4   If you did not choose Turkey as your first study abroad destination, which country did you originally choose? - If other please specify - Text                                                    271
# 5.5   What were the reasons you did not study in your first choice country? - Financial reasons                                                                                                         162
# 5.5   What were the reasons you did not study in your first choice country? - Difficulty obtaining a visa                                                                                               192
# 5.5   What were the reasons you did not study in your first choice country? - Family permission                                                                                                         200
# 5.5   What were the reasons you did not study in your first choice country? - Did not get accepted to desired university.                                                                               183
# 5.5   What were the reasons you did not study in your first choice country? - If others please specify                                                                                                  249
# 5.5   What were the reasons you did not study in your first choice country? - If others please specify - Text                                                                                           265
# 5.6   Did your current university (in Turkey) grant you a scholarship?                                                                                                                                   74
# 5.7   If yes, was this important in your decision of where to study?                                                                                                                                    197
# 5.8   What were your main reasons to study in Turkey? - I saw it as an opportunity to explore other cultures                                                                                             79
# 5.8   What were your main reasons to study in Turkey? - I wanted to internationalize myself                                                                                                              81
# 5.8   What were your main reasons to study in Turkey? - I found Turkey economically affordable                                                                                                           78
# 5.8   What were your main reasons to study in Turkey? - My family was keen of Turkey's Islamic culture                                                                                                   79
# 5.8   What were your main reasons to study in Turkey? - If others please specify                                                                                                                        224
# 5.8   What were your main reasons to study in Turkey? - If others please specify - Text                                                                                                                 253
# 5.9    What factors concerned you (before moving) to study in Turkey? - Difficulty with the language                                                                                                     76
# 5.9    What factors concerned you (before moving) to study in Turkey? - Wary to live in another country                                                                                                  81
# 5.9    What factors concerned you (before moving) to study in Turkey? - Concerned to leave family                                                                                                        78
# 5.9    What factors concerned you (before moving) to study in Turkey? - Concerned to get visa                                                                                                            80
# 5.9    What factors concerned you (before moving) to study in Turkey? - Not enough financial means to study abroad                                                                                       80
# 5.9    What factors concerned you (before moving) to study in Turkey? - If others (please specify)                                                                                                      241
# 5.9    What factors concerned you (before moving) to study in Turkey? - If others (please specify) - Text                                                                                               273
# 5.10   Would you like to live abroad after your studies?                                                                                                                                                 73
# 5.11   If yes, where would you like to live(a), and what career path would you want to pursue(b)? - a) Country                                                                                          152
# 5.11   If yes, where would you like to live(a), and what career path would you want to pursue(b)? - b) Career                                                                                           152
# 5.12   Do you intend to return to your country after graduation?                                                                                                                                         80
# 5.13   Have you traveled to Turkey before starting university?                                                                                                                                           75
# 5.14   If yes, how many times did you travel to Turkey?                                                                                                                                                 216
# 6.1   Did you need financial aid to study abroad?                                                                                                                                                        81
# 6.2   Which funding options are available to you? (Tick any that apply): - Selected Choice                                                                                                               76
# 6.2   Which funding options are available to you? (Tick any that apply): - Other (Please Specify) - Text                                                                                                270
# 6.3   Do you consider your study abroad as an adventure in a new country?                                                                                                                                76
# 7.1   Did any of your family members advise you to study abroad?                                                                                                                                         76
# 7.2   If yes, from which family member did you receive such advice? (Tick any that apply) - Selected Choice                                                                                             124
# 7.2   If yes, from which family member did you receive such advice? (Tick any that apply) - If other please specify - Text                                                                              275
# 7.3   Did any of your friends advise you to study abroad?                                                                                                                                                77
# 7.4   If yes, how close were you to the friend who gave you the advice?                                                                                                                                 138
# 7.5   Did anyone besides your friends and family recommend that you study abroad?                                                                                                                        77
# 7.6   If yes, who was it from? (Tick any that apply) - Selected Choice                                                                                                                                  174
# 7.6   If yes, who was it from? (Tick any that apply) - If other please specify - Text                                                                                                                   267
# 8.1   How many times did you return to your country during your last academic year?                                                                                                                      77
# 8.2   Aside from family members, do you keep in contact with friends?                                                                                                                                    77
# 8.3   If yes, how many friends have you contacted last week?                                                                                                                                             91
# 8.4   Regarding your social life, which statement is correct? - I mostly socialize with Turkish people                                                                                                   78
# 8.4   Regarding your social life, which statement is correct? - I mainly socialize with people from home country                                                                                         78
# 8.4   Regarding your social life, which statement is correct? - I generally socialize with other foreign students (Not including Turkish or home country)                                                78
# 8.5   How would you scale the following problems while studying in Turkey? - Turkish language                                                                                                            87
# 8.5   How would you scale the following problems while studying in Turkey? - Financial barriers                                                                                                          88
# 8.5   How would you scale the following problems while studying in Turkey? - Getting internships/jobs                                                                                                   122
# 8.5   How would you scale the following problems while studying in Turkey? - Quality of teaching                                                                                                         83
# 8.5   How would you scale the following problems while studying in Turkey? - Being far from parents                                                                                                      95
# 8.5   How would you scale the following problems while studying in Turkey? - Health services                                                                                                            106
# 8.5   How would you scale the following problems while studying in Turkey? - If others please specify                                                                                                   260
# 8.5   How would you scale the following problems while studying in Turkey? - If others please specify - Text                                                                                            265
# 8.6   Are you satisfied with your overall experience in Turkey?                                                                                                                                          78
# We would like to conduct follow-up interviews with a small number of students who have studied abroad. If you are interested in participating, please provide your e-mail address information below:    202
# dtype: int64

# %%
counts2 =df.groupby(['2.8  Please name your college/university']).count().iloc[:,:1].reset_index().sort_values(['1.1   I am/was an international student at a Turkish university.'],ascending=False)
sns.set_theme()
sns.barplot(data=counts2, y="2.8  Please name your college/university", x="1.1   I am/was an international student at a Turkish university.", orient='h', log=True)
# Out:
# <AxesSubplot:xlabel='1.1   I am/was an international student at a Turkish university.', ylabel='2.8  Please name your college/university'>

# %%
bar_data={'Always':2.88,  'Most of the times':2.97,'Half of time':3.069,'Sometimes':2.99,'Never':2.76}
sns.set_theme()

x1 = list(bar_data.keys())
y1 = list(bar_data.values())
sns.set(font_scale=5)
sns.set(rc={'figure.figsize':(11.7,8.27)})

sns.barplot( x=x1, y=y1)
# Out:
# <AxesSubplot:>

# %%
counts1 =df.groupby(['2.5  How do you identify yourself?']).count().iloc[:,:1].reset_index().sort_values(['1.1   I am/was an international student at a Turkish university.'],ascending=False)



sns.set_theme()
plt.rcParams["axes.labelsize"] = 15
sns.color_palette("light:#5A9", as_cmap=True)
sns.set(font_scale=5)
sns.set(rc={'figure.figsize':(11.7,8.27)})

ax= sns.barplot(data=counts1, x="2.5  How do you identify yourself?", y="1.1   I am/was an international student at a Turkish university.")
ax.set_xlabel(ax.get_xlabel(), fontdict={'weight': 'bold'})
ax.set_ylabel(ax.get_ylabel(), fontdict={'weight': 'bold'})
ax
plt.title('Gender distribution in the survey', weight='bold').set_fontsize('15')

# %%
counts2['2.7   What is your level of education? - Selected Choice'] = counts2['2.7   What is your level of education? - Selected Choice'].replace(['Diploma, technical qualification'], 'Diploma')
counts2['2.7   What is your level of education? - Selected Choice'] = counts2['2.7   What is your level of education? - Selected Choice'].replace(['If other please specify'], 'Others')
counts2
# Out:
#   2.7   What is your level of education? - Selected Choice  \
# 4                                      Undergraduate
# 1                                           Graduate
# 3                                                PHD
# 0                                            Diploma
# 2                                             Others
#
#    1.1   I am/was an international student at a Turkish university.
# 4                                                204
# 1                                                 12
# 3                                                  5
# 0                                                  2
# 2                                                  2

# %%
plt.style.use('ggplot')
plt.figure(figsize=(8,5))
sns.barplot(data=counts2, x="2.7   What is your level of education? - Selected Choice", y="1.1   I am/was an international student at a Turkish university.").set(xlabel='Level of Education', ylabel='Observation')
# Out:
# [Text(0.5, 0, 'Level of Education'), Text(0, 0.5, 'Observation')]

# %%
pd.crosstab(  df['2.5  How do you identify yourself?'], df['8.6   Are you satisfied with your overall experience in Turkey?'])
# Out:
# 8.6   Are you satisfied with your overall experience in Turkey?  Extremely dissatisfied  \
# 2.5  How do you identify yourself?
# Female                                                                                2
# Male                                                                                  2
# Non-binary                                                                            0
#
# 8.6   Are you satisfied with your overall experience in Turkey?  Extremely satisfied  \
# 2.5  How do you identify yourself?
# Female                                                                             6
# Male                                                                              14
# Non-binary                                                                         0
#
# 8.6   Are you satisfied with your overall experience in Turkey?  Neither satisfied nor dissatisfied  \
# 2.5  How do you identify yourself?
# Female                                                                                            8
# Male                                                                                             21
# Non-binary                                                                                        1
#
# 8.6   Are you satisfied with your overall experience in Turkey?  Somewhat dissatisfied  \
# 2.5  How do you identify yourself?
# Female                                                                               4
# Male                                                                                 7
# Non-binary                                                                           0
#
# 8.6   Are you satisfied with your overall experience in Turkey?  Somewhat satisfied
# 2.5  How do you identify yourself?
# Female                                                                           46
# Male                                                                             86
# Non-binary                                                                        0

# %%
pd.crosstab(  df['2.5  How do you identify yourself?'], df['8.6   Are you satisfied with your overall experience in Turkey?']).plot.bar()
# Out:
# <AxesSubplot:xlabel='2.5  How do you identify yourself?'>

# %%
pd.crosstab(df['5.8   What were your main reasons to study in Turkey? - I found Turkey economically affordable'],df['8.6   Are you satisfied with your overall experience in Turkey?'])
# Out:
# 8.6   Are you satisfied with your overall experience in Turkey?  Extremely dissatisfied  \
# 5.8   What were your main reasons to study in T...
# Moderately important                                                                  1
# Not important                                                                         0
# Very important                                                                        2
#
# 8.6   Are you satisfied with your overall experience in Turkey?  Extremely satisfied  \
# 5.8   What were your main reasons to study in T...
# Moderately important                                                               6
# Not important                                                                      2
# Very important                                                                    12
#
# 8.6   Are you satisfied with your overall experience in Turkey?  Neither satisfied nor dissatisfied  \
# 5.8   What were your main reasons to study in T...
# Moderately important                                                                              8
# Not important                                                                                     1
# Very important                                                                                   20
#
# 8.6   Are you satisfied with your overall experience in Turkey?  Somewhat dissatisfied  \
# 5.8   What were your main reasons to study in T...
# Moderately important                                                                 5
# Not important                                                                        0
# Very important                                                                       6
#
# 8.6   Are you satisfied with your overall experience in Turkey?  Somewhat satisfied
# 5.8   What were your main reasons to study in T...
# Moderately important                                                             32
# Not important                                                                     6
# Very important                                                                   91

# %%
df['2.1   What is your country of citizenship?'].nunique()
# Out:
# 37

# %%
bins= [0,15,20,25,30]
labels = ['0-15','15-20','20-25','25-30']
a = pd.cut(df['2.4   How old are you?'], bins=bins, labels=labels, right=False)
print (a.value_counts())
# Out:
# 20-25    142
# 15-20     69
# 25-30      8
# 0-15       0
# Name: 2.4   How old are you?, dtype: int64

# %%
data = [142, 69, 8]
keys = ['15-20', '20-25', '25-30']
  
# define Seaborn color palette to use
palette_color = sns.color_palette('pastel')[0:5]
sns.set_theme()  
# plotting data on chart
plt.pie(data, labels=keys, colors=palette_color, autopct='%.0f%%')
  
# displaying chart
plt.show()

# %%
df['2.7   What is your level of education? - Selected Choice'].value_counts(normalize=True)
# Out:
# Undergraduate                       0.906667
# Graduate                            0.053333
# PHD                                 0.022222
# Diploma, technical qualification    0.008889
# If other please specify             0.008889
# Name: 2.7   What is your level of education? - Selected Choice, dtype: float64
